# %%
import torch
import pandas as pd
import numpy as np

# Vérification M1
DEVICE = (
    "mps"  if torch.backends.mps.is_available() else
    "cuda" if torch.cuda.is_available()          else
    "cpu"
)
print(f"PyTorch    : {torch.__version__}")
print(f"Device     : {DEVICE}")
print(f"Pandas     : {pd.__version__}")
print(f"NumPy      : {np.__version__}")
print("Tout est prêt ✓" if DEVICE == "mps" else f"Attention : device = {DEVICE}")
# Out:
# PyTorch    : 2.11.0
# Device     : mps
# Pandas     : 3.0.2
# NumPy      : 2.4.4
# Tout est prêt ✓
